# %% [markdown]
# ### Problem 1
# #### Milad Heidari
# #### Student Number: 98101469

# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn as nn

# %%
# set device to cuda if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# language class to convert words into one-hot vectors and vice-versa

SOS_TOKEN = 0
EOS_TOKEN = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: 'SOS', 1: 'EOS'}
        self.n_words = 2    # currently we have SOS & EOS
        
    def add_sentence(self, sentence):
        for word in sentence.split(' '):
            self.add_word(word)
            
    def add_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# preparing training data

def indexes_from_sentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensor_from_sentence(lang, sentence):
    indexes = indexes_from_sentence(lang, sentence)
    indexes.append(EOS_TOKEN)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensors_from_pair(pair):
    input_tensor = tensor_from_sentence(farsi, pair[0])
    target_tensor = tensor_from_sentence(farsi, pair[1])
    return (input_tensor, target_tensor)

# %%
farsi = Lang(name='Farsi')

# %%
with open('ferdousi.txt', 'r') as f:
    all_lines = [line.strip() for line in f]

# %%
for line in all_lines:
    farsi.add_sentence(line)

# %%
io_pairs = list(zip(all_lines[::2], all_lines[1::2]))

# %%
train_size = int(len(io_pairs) * 0.95)
train_data = io_pairs[:train_size]
test_data = io_pairs[train_size:]

# %%
# beyts = []
# for i in range(0, len(all_lines), 2):
#     beyts.append(all_lines[i] + ' ' + all_lines[i+1])

# %%
# io_pairs = []
# for i in range(1, len(beyts)-1, 2):
#     io_pairs.append((beyts[i-1], beyts[i]))
#     io_pairs.append((beyts[i], beyts[i+1]))

# %% [markdown]
# #### GRU

# %%
# the encoder network
class EncoderRNN(nn.Module):
    
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        
    def forward(self, input_, hidden):
        embedded = self.embedding(input_).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden
        
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, input_, hidden):
        output = self.embedding(input_).view(1, 1, -1)
        output = nn.functional.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden
    
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
# define training loop

def train(input_tensor, target_tensor, encoder, decoder,
          encoder_optimizer, decoder_optimizer, criterion):
    
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)

    decoder_input = torch.tensor([[SOS_TOKEN]], device=device)

    decoder_hidden = encoder_hidden

    loss = 0
    for di in range(target_length):
        decoder_output, decoder_hidden = decoder(
            decoder_input, decoder_hidden)
        loss += criterion(decoder_output, target_tensor[di])
        decoder_input = target_tensor[di]


    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
# define encoder and decoder models
hidden_size = 256
encoder = EncoderRNN(farsi.n_words, hidden_size).to(device)
decoder = DecoderRNN(hidden_size, farsi.n_words).to(device)

# %%
# define optimizers and loss function and hyperparameters
learning_rate = 1e-3
num_epochs = 3

encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss()

# %%
# train the models
for i in range(num_epochs):
    losses = []
    for j, pair in enumerate(train_data):
        input_tensor, target_tensor = tensors_from_pair(pair)
        loss = train(input_tensor, target_tensor, encoder, decoder,
                    encoder_optimizer, decoder_optimizer, loss_fn)
        losses.append(loss)
        if j % 10000 == 1:
            print(j)
            print(f'average loss: {np.mean(losses)}')
            losses = []
    print(f'epoch: {i}')
    print(f'loss: {loss}')
    print()

# %%
# evaluating the model
def evaluate(encoder, decoder, sentence):
    with torch.no_grad():
        input_tensor = tensor_from_sentence(farsi, sentence)
        input_length = input_tensor.size(0)
        encoder_hidden = encoder.initHidden()

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)

        decoder_input = torch.tensor([[SOS_TOKEN]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        
        max_length = 20

        for di in range(20):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_TOKEN:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(farsi.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words

# %%
for pair in test_data:
    input_sentence, target_sentence = pair
    decoded_words = evaluate(encoder, decoder, input_sentence)
    output_sentence = ' '.join(decoded_words) if '<EOS>' not in decoded_words else ' '.join(decoded_words[:-1])
    
    print()
    print(f'input sentence: ')
    print(input_sentence)
    print('model output: ')
    print(output_sentence)
    print('target sentence: ')
    print(target_sentence)
    print()

# %% [markdown]
# #### LSTM

# %%
# the encoder network
class EncoderRNN(nn.Module):
    
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        
    def forward(self, input_, hidden, c):
        embedded = self.embedding(input_).view(1, 1, -1)
        output = embedded
        output, (hidden, c) = self.lstm(output, (hidden, c))
        return output, hidden, c
        
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)
    
    def initC(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, input_, hidden, c):
        output = self.embedding(input_).view(1, 1, -1)
        output = nn.functional.relu(output)
        output, (hidden, c) = self.lstm(output, (hidden, c))
        output = self.softmax(self.out(output[0]))
        return output, hidden, c
    
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)
    
    def initC(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
# define training loop

def train(input_tensor, target_tensor, encoder, decoder,
          encoder_optimizer, decoder_optimizer, criterion):
    
    encoder_hidden = encoder.initHidden()
    encoder_c = encoder.initC()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    for ei in range(input_length):
        encoder_output, encoder_hidden, encoder_c = encoder(
            input_tensor[ei], encoder_hidden, encoder_c)

    decoder_input = torch.tensor([[SOS_TOKEN]], device=device)

    decoder_hidden = encoder_hidden
    decoder_c = encoder_c

    loss = 0
    for di in range(target_length):
        decoder_output, decoder_hidden, decoder_c = decoder(
            decoder_input, decoder_hidden, decoder_c)
        loss += criterion(decoder_output, target_tensor[di])
        decoder_input = target_tensor[di]


    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
# define encoder and decoder models
hidden_size = 256
encoder = EncoderRNN(farsi.n_words, hidden_size).to(device)
decoder = DecoderRNN(hidden_size, farsi.n_words).to(device)

# %%
# define optimizers and loss function and hyperparameters
learning_rate = 1e-3
num_epochs = 3

encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss()

# %%
# train the models
for i in range(num_epochs):
    losses = []
    for j, pair in enumerate(io_pairs):
        input_tensor, target_tensor = tensors_from_pair(pair)
        loss = train(input_tensor, target_tensor, encoder, decoder,
                    encoder_optimizer, decoder_optimizer, loss_fn)
        losses.append(loss)
        if j % 10000 == 1:
            print(j)
            print(f'average loss: {np.mean(losses)}')
            losses = []
    print(f'epoch: {i}')
    print(f'loss: {loss}')
    print()
# Out:
# 1
# average loss: 9.777871704101562
# 10001
# average loss: 5.975199633708414
# 20001
# average loss: 5.604064052663703
# 30001
# average loss: 5.564688232538077
# 40001
# average loss: 5.544520335962773
# epoch: 0
# loss: 3.8248498099190846
#
# 1
# average loss: 5.20924129486084
# 10001
# average loss: 5.201848017936159
# 20001
# average loss: 5.066076602748764
# 30001
# average loss: 5.025530012290231
# 40001
# average loss: 5.011335315371864
# epoch: 1
# loss: 3.672532762799944
#
# 1
# average loss: 4.932137870788575
# 10001
# average loss: 4.80185193531053
# 20001
# average loss: 4.716161025853699
# 30001
# average loss: 4.709846325249476
# 40001
# average loss: 4.709697977345485
# epoch: 2
# loss: 3.9775289808000838

# %%
# evaluating the model
def evaluate(encoder, decoder, sentence):
    with torch.no_grad():
        input_tensor = tensor_from_sentence(farsi, sentence)
        input_length = input_tensor.size(0)
        encoder_hidden = encoder.initHidden()
        encoder_c = encoder.initC()

        for ei in range(input_length):
            encoder_output, encoder_hidden, encoder_c = encoder(
                input_tensor[ei], encoder_hidden, encoder_c)

        decoder_input = torch.tensor([[SOS_TOKEN]], device=device)  # SOS

        decoder_hidden = encoder_hidden
        decoder_c = encoder_c

        decoded_words = []
        
        max_length = 20

        for di in range(20):
            decoder_output, decoder_hidden, decoder_c = decoder(
                decoder_input, decoder_hidden, decoder_c)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_TOKEN:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(farsi.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words

# %%
for pair in test_data:
    input_sentence, target_sentence = pair
    decoded_words = evaluate(encoder, decoder, input_sentence)
    output_sentence = ' '.join(decoded_words) if '<EOS>' not in decoded_words else ' '.join(decoded_words[:-1])
    
    print()
    print(f'input sentence: ')
    print(input_sentence)
    print('model output: ')
    print(output_sentence)
    print('target sentence: ')
    print(target_sentence)
    print()
# Out:
# input sentence:
# فرستاد چون مرد رومی چهل
# model output:
# به پیش اندرون ساخته هفت
# target sentence:
# کجا هر چهل بود بیدار دل
#
#
# input sentence:
# گوی پیش رو نام او خانگی
# model output:
# که با او به یزدان نیکی دهش
# target sentence:
# که همتا نبودش به فرزانگی
#
#
# input sentence:
# همی شد برین گونه با ساروان
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# شتربار دینار ده کاروان
#
#
# input sentence:
# چوآگاهی آمد به پرویز شاه
# model output:
# که ای شاه را پیش سپاه
# target sentence:
# که پیغمبر قیصر آمد ز راه
#
#
# input sentence:
# به فرخ بفرمود تا برنشست
# model output:
# به پیش سپاه اندر میان
# target sentence:
# یکی مرزبان بود خسروپرست
#
#
# input sentence:
# که سالار او بود بر نیمروز
# model output:
# به پیش اندرون ساخته گیتی فروز
# target sentence:
# گرانمایه گردی و گیتی فروز
#
#
# input sentence:
# برفتند با او سواران شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# به سر برنهادند زرین کلاه
#
#
# input sentence:
# چو از دور دید آن سپه خانگی
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# به پیش اندر آمد به بیگانگی
#
#
# input sentence:
# چنین تا به نزدیک شاه آمدند
# model output:
# به پیش اندرون ساخته آمدند
# target sentence:
# بران نامور پیشگاه آمدند
#
#
# input sentence:
# چو دیدند زیبا رخ شاه را
# model output:
# به پیش سپاه آن کیانی گاه
# target sentence:
# بران گونه آراسته گاه را
#
#
# input sentence:
# نهادند همواره سر بر زمین
# model output:
# به پیش اندرون ساخته زمین
# target sentence:
# برو بر همی خواندند آفرین
#
#
# input sentence:
# بمالید پس خانگی رخ بخاک
# model output:
# به پیش اندرون ساخته بر خاک
# target sentence:
# همی گفت کای داور داد وپاک
#
#
# input sentence:
# ز پیروزگر آفرین بر تو باد
# model output:
# که با من به خوبی نگیرند باد
# target sentence:
# مبادی همیشه مگر شاه و راد
#
#
# input sentence:
# بزرگانش از جای برخاستند
# model output:
# به پیش اندرون ساخته آراستند
# target sentence:
# به نزدیک شه جایش آراستند
#
#
# input sentence:
# چنین گفت پس شاه را خانگی
# model output:
# که این را به خوبی چنو تاج و تخت
# target sentence:
# که چون تو که باشد به فرزانگی
#
#
# input sentence:
# ز خورشید بر چرخ تابنده تر
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# ز جان سخنگوی پاینده تر
#
#
# input sentence:
# مبادا جهان بی چنین شهریار
# model output:
# که ای شاه چندان سرآمد به کار
# target sentence:
# برومند بادا برو روزگار
#
#
# input sentence:
# مبیناد کس روز بی کام تو
# model output:
# که این را به خوبی رسد تو نام
# target sentence:
# نوشته بخورشید بر نام تو
#
#
# input sentence:
# جهان بی سر و افسر تو مباد
# model output:
# به پیش اندرون بر سرش دین
# target sentence:
# بر و بوم بی لشکر تو مباد
#
#
# input sentence:
# ز قیصر درود و ز ما آفرین
# model output:
# که این را به خوبی و دین وتخت
# target sentence:
# برین نامور شهریار زمین
#
#
# input sentence:
# کسی کو درین سایهٔ شاه شاد
# model output:
# که با تو مبادا که آید به داد
# target sentence:
# نباشد ورا روشنایی مباد
#
#
# input sentence:
# ابا هدیه و باژ روم آمدم
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# برین نامبردار بوم آمدم
#
#
# input sentence:
# برفتیم با فیلسوفان بهم
# model output:
# که با من به خوبی کشنده دژم
# target sentence:
# بران تا نباشد کس از ما دژم
#
#
# input sentence:
# ز قیصر پذیرد مگر باژ و چیز
# model output:
# که با او به یزدان مشو نیز
# target sentence:
# که با باژ و چیز آفرینست نیز
#
#
# input sentence:
# بخندید از آن پر هنر مرد شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# نهادند زرین یکی پیشگاه
#
#
# input sentence:
# فرستاد پس چیزها سوی گنج
# model output:
# که با او به یزدان نیکی شناس
# target sentence:
# بدو گفت چندین نبایست رنج
#
#
# input sentence:
# بخراد بر زین چنین گفت شاه
# model output:
# که ای شاه را نیست جوینده راه
# target sentence:
# که این نامه برخوان به پیش سپاه
#
#
# input sentence:
# به عنوان نگه کرد مرد دبیر
# model output:
# به پیش اندرون نیزه وران
# target sentence:
# که گوینده ای بود و هم یادگیر
#
#
# input sentence:
# چنین گفت کاین نامه سوی مهست
# model output:
# که با او به یزدان نجست
# target sentence:
# جهاندار پرویز یزدان پرست
#
#
# input sentence:
# جهاندار و بیدار و پدرام شهر
# model output:
# که با او به یزدان مشو را بهر
# target sentence:
# که یزدانش تاج و خرد داد بهر
#
#
# input sentence:
# جهاندار فرزند هرمزد شاه
# model output:
# که با او به فرمان او تاج شاه
# target sentence:
# که زیبای تاج است و زیبای گاه
#
#
# input sentence:
# ز قیصر پدر مادر شیر نام
# model output:
# که با او به گیتی همی شادکام
# target sentence:
# که پاینده بادا بدو نام و کام
#
#
# input sentence:
# ابا فر و با برز و پیروز باد
# model output:
# به پیش سپاه اندر آمد بباد
# target sentence:
# همه روزگارانش نوروز باد
#
#
# input sentence:
# به ایران و تورانش بر دست رس
# model output:
# به پیش سپاه اندر آرم گمان
# target sentence:
# به شاهی مباداش انباز کس
#
#
# input sentence:
# همیشه به دل شاد و روشن روان
# model output:
# که با او به بیهوده دانا شمر
# target sentence:
# همیشه خرد پیر و دولت جوان
#
#
# input sentence:
# گران مایه شاهی کیومرثی
# model output:
# به پیش اندرون گونه ای برگذشت
# target sentence:
# همان پور هوشنگ طهمورثی
#
#
# input sentence:
# پدر بر پدر و پسر بر پسر
# model output:
# که ای شاه را پیش او را ندید
# target sentence:
# مبادا که این گوهر آید به سر
#
#
# input sentence:
# برین پاک یزدان کند آفرین
# model output:
# که این را به خوبی و دین وتخت
# target sentence:
# بزرگان ملک و بزرگان دین
#
#
# input sentence:
# نه چون تو خزان و نه چون تو بهار
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# نه چون تو بایوان چین بر نگار
#
#
# input sentence:
# همه مردمی و همه راستی
# model output:
# به پیش اندرون ساخته کاستی
# target sentence:
# مبیناد جانت بد کاستی
#
#
# input sentence:
# به ایران و توران و هندوستان
# model output:
# که با من به خوبی چنو نیست راز
# target sentence:
# همان ترک تا روم و جا دوستان
#
#
# input sentence:
# تو را داد یزدان به پاکی نژاد
# model output:
# که با من به نیکی دهش کرد یاد
# target sentence:
# کسی چون تو از پاک مادر نزاد
#
#
# input sentence:
# فریدون چو ایران بایرج سپرد
# model output:
# که این را به خوبی چنو نیست گرد
# target sentence:
# ز روم و ز چین نام مردی ببرد
#
#
# input sentence:
# برو آفرین کرد روز نخست
# model output:
# که با او به گیتی همی جست
# target sentence:
# دلش را ز کژی و تاری بشست
#
#
# input sentence:
# همه بی نیازی و نیک اختری
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# بزرگی و مردی و افسونگری
#
#
# input sentence:
# تو گویی که یزدان شما را سپرد
# model output:
# که این را به خوبی چنو نیست گرد
# target sentence:
# وزان دیگران نام مردی ببرد
#
#
# input sentence:
# هنر پرور و راد و بخشنده گنج
# model output:
# که با تو مبادا به فرمان دهی
# target sentence:
# ازین تخمهٔ هرگز نبد کس به رنج
#
#
# input sentence:
# نهادند بر دشمنان باژ و ساو
# model output:
# که با او به گیتی کسی را زیان
# target sentence:
# بد اندیشتان بارکش همچو گاو
#
#
# input sentence:
# ز هنگام کسری نوشین روان
# model output:
# که با او به باغ آمد روان
# target sentence:
# که بادا همیشه روانش جوان
#
#
# input sentence:
# که از ژرف دریا برآورد پی
# model output:
# به پیش اندرون ساخته چند زار
# target sentence:
# بران گونه دیوار بیدار کی
#
#
# input sentence:
# ز ترکان همه بیشهٔ نارون
# model output:
# به پیش اندرون ساخته هفت
# target sentence:
# بشستند وبی رنج گشت انجمن
#
#
# input sentence:
# ز دشمن برستند چندی جهان
# model output:
# که با من به نیکی دهش آشکار
# target sentence:
# برو آفرین از کهان و مهان
#
#
# input sentence:
# ز تازی و هندی و ایرانیان
# model output:
# به پیش اندرون ساخته چند زیان
# target sentence:
# ببستند پیشش کمر بر میان
#
#
# input sentence:
# روا رو چنین تا به مرز خزر
# model output:
# که با او به یزدان نجست
# target sentence:
# ز ارمینیه تا در باختر
#
#
# input sentence:
# ز هیتال و ترک و سمرقند و چاچ
# model output:
# به پیش سپاه اندر آورده روی
# target sentence:
# بزرگان با فر او اورند وتاج
#
#
# input sentence:
# همه کهتران شما بوده اند
# model output:
# که با من به خوبی زمانی اند
# target sentence:
# برین بندگی بر گوا بوده اند
#
#
# input sentence:
# که شاهان ز تخم فریدون بدند
# model output:
# به پیش اندرون بر سرش بیرون بدند
# target sentence:
# دگر یکسر از داد بیرون بدند
#
#
# input sentence:
# بدین خویشی اکنون که من کرده ام
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# بزرگی به دانش برآورده ام
#
#
# input sentence:
# بدان گونه شادم که تشنه بر آب
# model output:
# به پیش اندرون ساخته آفتاب
# target sentence:
# وگر سبزهٔ تیره بر آفتاب
#
#
# input sentence:
# جهاندار بیدار فرخ کناد
# model output:
# که با من به گیتی به هامون برند
# target sentence:
# مرا اندرین روز پاسخ کناد
#
#
# input sentence:
# یکی آرزو خواهم از شهریار
# model output:
# که این را به خوبی برو روزگار
# target sentence:
# کجا آن سخن نزد او هست خوار
#
#
# input sentence:
# که دار مسیحا به گنج شماست
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# چو بینید دانید گفتار راست
#
#
# input sentence:
# برآمد برین سالیان دراز
# model output:
# که با او به گیتی همی باز
# target sentence:
# سزد گر فرستد بما شاه باز
#
#
# input sentence:
# بدین آرزو شهریار جهان
# model output:
# که با من به خوبی کشنده کهان و مهان
# target sentence:
# ببخشاید از ما کهان و مهان
#
#
# input sentence:
# ز گیتی برو بر کنند آفرین
# model output:
# که ای شاه چندان نماند ایچ کین
# target sentence:
# که بی تو مبادا زمان و زمین
#
#
# input sentence:
# بدان من ز خسرو پذیرم سپاس
# model output:
# که با او به نیکی دهش رهنمای
# target sentence:
# نیایش کنم روز و شب در سه پاس
#
#
# input sentence:
# همان هدیه و باژ و ساوی که من
# model output:
# به پیش سپاه اندر آرم تن
# target sentence:
# فرستم به نزدیک آن انجمن
#
#
# input sentence:
# پذیرد پذیرم سپاسی بدان
# model output:
# که با من به خوبی زمانی فزود
# target sentence:
# مبیناد چشم تو روی بدان
#
#
# input sentence:
# شود فرخ این جشن و آیین ما
# model output:
# که با من به خوبی برو بر ما
# target sentence:
# درخشان شود در جهان دین ما
#
#
# input sentence:
# همان روزهٔ پاک یک شنبدی
# model output:
# که با او به یزدان مشو را گره
# target sentence:
# ز هر در پرستندهٔ ایزدی
#
#
# input sentence:
# برو سوکواران بمالند روی
# model output:
# به پیش اندرون ساخته جنگجوی
# target sentence:
# بروبر فراوان بسایند موی
#
#
# input sentence:
# شود آن زمان بر دل ما درست
# model output:
# که با من به خوبی چنو نیست
# target sentence:
# که از کینه دلها بخواهیم شست
#
#
# input sentence:
# که بود از گه آفریدون فراز
# model output:
# که با او به گیتی همی بشمرد
# target sentence:
# که با تور و سلم اندر آمد براز
#
#
# input sentence:
# شود کشور آسوده از تاختن
# model output:
# که با من به خوبی کشنده بیاراستند
# target sentence:
# بهر گوشه ای کینها ساختن
#
#
# input sentence:
# زن و کودک رومیان برده اند
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# دل ما ز هر گونه آزرده اند
#
#
# input sentence:
# برین خویشی ما جهان رام گشت
# model output:
# به پیش سپاه اندر آمد گذشت
# target sentence:
# همه کار بیهوده پدرام گشت
#
#
# input sentence:
# درود جهان آفرین بر تو باد
# model output:
# که با من به خوبی نگیرند باد
# target sentence:
# همان آفرین زمین بر تو باد
#
#
# input sentence:
# چو آن نامهٔ قیصر آمد ببن
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# جهاندار بشنید چندان سخن
#
#
# input sentence:
# ازان نامه شد شاه خرم نهان
# model output:
# که گفتی برو بر جهان پهلوان
# target sentence:
# برو تازه شد روزگار مهان
#
#
# input sentence:
# بسی آفرین کرد برخانگی
# model output:
# که این را به خوبی زمانی نهفت
# target sentence:
# بدو گفت بس کن ز بیگانگی
#
#
# input sentence:
# گرانمایه را جایگه ساختند
# model output:
# به پیش اندرون نیزه وران
# target sentence:
# دو ایوان فرخ بپرداختند
#
#
# input sentence:
# ببردند چیزی که بایست برد
# model output:
# که با او به یزدان سخنها براند
# target sentence:
# به نزدیک آن مرد بیدار گرد
#
#
# input sentence:
# بیامد بدید آن گزین جایگاه
# model output:
# به پیش اندرون ساخته راه شاه
# target sentence:
# وزان پس همی بود نزدیک شاه
#
#
# input sentence:
# بخوان و نبید و شکار و نشست
# model output:
# که با او به گیتی همی دست
# target sentence:
# همی بود با شاه مهتر پرست
#
#
# input sentence:
# برین گونه یک ماه نزدیک شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# همی بود شادان دل و نیک خواه
#
#
# input sentence:
# چویک ماه شد نامه پاسخ نوشت
# model output:
# به پیش اندرون نیزه ور بی زشت
# target sentence:
# سخنهای با مغز و فرخ نوشت
#
#
# input sentence:
# سرنامه گفت آفرین مهان
# model output:
# که این را به خوبی جهان یادگار
# target sentence:
# بران باد کو باد دارد جهان
#
#
# input sentence:
# بد و نیک بیند ز یزدان پاک
# model output:
# که با او به یزدان نیکی توی
# target sentence:
# وزو دارد اندر جهان بیم و باک
#
#
# input sentence:
# کند آفرین بر خداوند مهر
# model output:
# که با من به راه اندر آرم سپهر
# target sentence:
# کزین گونه بر پای دارد سپهر
#
#
# input sentence:
# نخست آنک کردی ستایش مرا
# model output:
# که با من به خوبی مرا رهنمای
# target sentence:
# به نامه نمودی نیایش مرا
#
#
# input sentence:
# بدانستم و شاد گشتم بدان
# model output:
# که با من به خوبی چنو کینه خواه
# target sentence:
# سخن گفتن تاجور بخردان
#
#
# input sentence:
# پذیرفتم آن نامور گنج تو
# model output:
# که این را به خوبی تو را نیست رنج
# target sentence:
# نخواهم که چندان بود رنج تو
#
#
# input sentence:
# ازی را جهاندار یزدان پاک
# model output:
# که با من به خوبی کشنده مپای
# target sentence:
# برآورد بوم تو را بر سماک
#
#
# input sentence:
# ز هند و ز سقلاب و چین و خزر
# model output:
# که با او به یزدان نجست
# target sentence:
# چنین ارجمند آمد آن بوم و بر
#
#
# input sentence:
# چه مردی چه دانش چه پرهیز و دین
# model output:
# که با من به خوبی کشنده دین زمین
# target sentence:
# ز یزدان شما را رسید آفرین
#
#
# input sentence:
# چو کار آمدم پیش یارم بدی
# model output:
# به پیش اندرون ساخته بدی
# target sentence:
# بهر دانشی غمگسارم بدی
#
#
# input sentence:
# چنان شاد گشتم ز پیوند تو
# model output:
# که این را به خوبی رسد نیست گاه
# target sentence:
# بدین پر هنر پاک فرزند تو
#
#
# input sentence:
# که کهتر نباشد به فرزند خویش
# model output:
# به پیش سپاه اندر آرم سرش
# target sentence:
# ببوم و بر و پاک پیوند خویش
#
#
# input sentence:
# همه مهتران پشت برگاشتند
# model output:
# به پیش اندرون ساخته بگذاشتند
# target sentence:
# مرا در جهان خوار بگذاشتند
#
#
# input sentence:
# تو تنها بجای پدر بودیم
# model output:
# که با من به خوبی کشنده درشت
# target sentence:
# همان از پدر بیشتر بودیم
#
#
# input sentence:
# تو را همچنان دارم اکنون که شاه
# model output:
# که با من به خوبی کشنده سپاه
# target sentence:
# پدر بیند آزاده و نیک خواه
#
#
# input sentence:
# دگر هرچ گفتی ز شیروی من
# model output:
# به پیش سپاه اندر آرم آزار من
# target sentence:
# ازان پاک تن پشت و نیروی من
#
#
# input sentence:
# بدانستم و آفرین خواندم
# model output:
# که با من به خوبی کنند آفرین
# target sentence:
# بران دین تو را پاک دین خواندم
#
#
# input sentence:
# دگر هرچ گفتی ز پاکیزه دین
# model output:
# که با او به یزدان مشو را دین
# target sentence:
# ز یک شنبدی روزهٔ به آفرین
#
#
# input sentence:
# همه خواند بر ما یکایک دبیر
# model output:
# به پیش اندرون نیزه وران
# target sentence:
# سخنهای بایسته و دلپذیر
#
#
# input sentence:
# بما بر ز دین کهن ننگ نیست
# model output:
# که با من به گیتی به نیست نیست
# target sentence:
# به گیتی به از دین هوشنگ نیست
#
#
# input sentence:
# همه داد و نیکی و شرمست و مهر
# model output:
# به پیش سپاه اندر آرم سپهر
# target sentence:
# نگه کردن اندر شمار سپهر
#
#
# input sentence:
# به هستی یزدان نیوشان ترم
# model output:
# که با او به گیتی همی کرد
# target sentence:
# همیشه سوی داد کوشان ترم
#
#
# input sentence:
# ندانیم انباز و پیوند و جفت
# model output:
# که با من به خوبی زمانی دراز
# target sentence:
# نگردد نهان و نگردد نهفت
#
#
# input sentence:
# در اندیشهٔ دل نگنجد خدای
# model output:
# که با من به خوبی کشنده رهنمای
# target sentence:
# به هستی همو با شدت رهنمای
# input sentence:
# دگر کت ز دار مسیحا سخن
# model output:
# که با او به خوبی افگند بن
# target sentence:
# بیاد آمد از روزگار کهن
#
#
# input sentence:
# مدان دین که باشد به خوبی بپای
# model output:
# که با او به یزدان نیکی شناس
# target sentence:
# بدان دین نباشد خرد رهنمای
#
#
# input sentence:
# کسی را که خوانی همی سوگوار
# model output:
# که با او به گیتی همی نیست بزم
# target sentence:
# که کردند پیغمبرش را بدار
#
#
# input sentence:
# که گوید که فرزند یزدان بد اوی
# model output:
# که با تو مبادا که آید بروی
# target sentence:
# بران دار بر کشته خندان بد اوی
#
#
# input sentence:
# چو پور پدر رفت سوی پدر
# model output:
# به پیش سپاه اندر آمد گذر
# target sentence:
# تو اندوه این چوب پوده مخور
#
#
# input sentence:
# ز قیصر چو بیهوده آمد سخن
# model output:
# به پیش اندرون ساخته کهن
# target sentence:
# بخندد برین کار مرد کهن
#
#
# input sentence:
# همان دار عیسی نیرزد به رنج
# model output:
# که با او به یزدان مشو را به گنج
# target sentence:
# که شاهان نهادند آن را به گنج
#
#
# input sentence:
# از ایران چو چوبی فرستم بروم
# model output:
# که با او به یزدان پرست
# target sentence:
# بخندد بما بر همه مرز و بوم
#
#
# input sentence:
# به موبد نباید که ترسا شدم
# model output:
# که با من به خوبی زمانی سران
# target sentence:
# گر از بهر مریم سکوبا شدم
#
#
# input sentence:
# دگر آرزو هرچ باید بخواه
# model output:
# که با من به نیکی دهش را نگاه
# target sentence:
# شمار سوی ما گشادست راه
#
#
# input sentence:
# پسندیدم آن هدیه های تو نیز
# model output:
# که با من به خوبی نیاید به چیز
# target sentence:
# کجا رنج بردی ز هر گونه چیز
#
#
# input sentence:
# به شیروی بخشیدم این برده رنج
# model output:
# که با من به خوبی کشنده سرای سپنج
# target sentence:
# پی افگندم او را یکی تازه گنج
#
#
# input sentence:
# ز روم و ز ایران پر اندیشه ام
# model output:
# به پیش اندرون ساخته رود بهار
# target sentence:
# شب تیره اندیشه شد پیشه ام
#
#
# input sentence:
# بترسم که شیروی گردد بلند
# model output:
# به پیش سپاه اندر آید گزند
# target sentence:
# ز ساند بروم و به ایران گزند
#
#
# input sentence:
# نخست اندر آید ز سلم بزرگ
# model output:
# که با او به گیتی به خوبی سترگ
# target sentence:
# ز اسکندر آن کینه دار سترگ
#
#
# input sentence:
# ز کین نو آیین و کین کهن
# model output:
# به پیش اندرون ساخته آفتاب
# target sentence:
# مگر در جهان تازه گردد سخن
#
#
# input sentence:
# سخنها که پرسیدم از دخترت
# model output:
# به پیش اندرون ساخته بیش و کم
# target sentence:
# چنان دان که او تازه کرد افسرت
#
#
# input sentence:
# بدین مسیحا بکوشد همی
# model output:
# همان تخت و افسر همی
# target sentence:
# سخنهای ما کم نیوشد همی
#
#
# input sentence:
# به آرام شادست و پیروزبخت
# model output:
# که با تو مبادا که آید به تخت
# target sentence:
# بدین خسروانی نو آیین درخت
#
#
# input sentence:
# همیشه جهاندار یار تو باد
# model output:
# که با من به خوبی زمانی تو
# target sentence:
# سر اختر اندر کنار تو باد
#
#
# input sentence:
# نهادند بر نامه بر مهر شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# همی داشت خراد برزین نگاه
#
#
# input sentence:
# گشادند زان پس در گنج باز
# model output:
# به پیش اندرون ساخته راز
# target sentence:
# کجا گرد کرد او به روز دراز
#
#
# input sentence:
# نخستین صد و شست بند اوسی
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# که پند او سی خواندش پارسی
#
#
# input sentence:
# به گوهر بیاگنده هر یک چو سنگ
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# نهادند بر هر یکی مهر تنگ
#
#
# input sentence:
# بران هر یکی دانه ها صد هزار
# model output:
# که با او به گیتی همی کارزار
# target sentence:
# بها بود بر دفتر شهریار
#
#
# input sentence:
# بیاورد سیصد شتر سرخ موی
# model output:
# به پیش اندرون ساخته چند گرد
# target sentence:
# سیه چشم و آراسته راه جوی
#
#
# input sentence:
# مران هر یکی را درم دو هزار
# model output:
# که با او به گیتی همی کارزار
# target sentence:
# بها داده بد نامور شهریار
#
#
# input sentence:
# ز دیبای چینی صد و چل هزار
# model output:
# که با او به گیتی همی بود کار
# target sentence:
# ازان چند زربفت گوهرنگار
#
#
# input sentence:
# دگر پانصد در خوشاب بود
# model output:
# که با او به یزدان نباید شنود
# target sentence:
# که هر دانه یی قطرهٔ آب بود
#
#
# input sentence:
# صد و شست یاقوت چون ناردان
# model output:
# به پیش سپاه اندر آرم فروغ
# target sentence:
# پسندیدهٔ مردم کاردان
#
#
# input sentence:
# ز هندی و چینی و از بربری
# model output:
# به پیش اندرون ساخته چند
# target sentence:
# ز مصری و از جامهٔ پهلوی
#
#
# input sentence:
# ز چیزی که خیزد ز هر کشوری
# model output:
# که با او به گیتی کسی را روان
# target sentence:
# که چونان نبد در جهان دیگری
#
#
# input sentence:
# فرستاد سیصد شتروار بار
# model output:
# به پیش اندرون ساخته شهریار
# target sentence:
# از ایران بر قیصر نامدار
#
#
# input sentence:
# یکی خلعت افگند بر خانگی
# model output:
# که با او به یزدان نیکی دهش
# target sentence:
# فزون تر ز خویشی و بیگانگی
#
#
# input sentence:
# همان جامه و تخت و اسب و ستام
# model output:
# به پیش اندرون ساخته تنگ
# target sentence:
# ز پوشیدنیها که بردیم نام
#
#
# input sentence:
# بدینسان چنین صد شتر بارکرد
# model output:
# که با او به گیتی همی کرد
# target sentence:
# از آن ده شتربار دینار کرد
#
#
# input sentence:
# ببخشید بر فیلسوفان درم
# model output:
# که با من به خوبی کشنده بسوخت
# target sentence:
# ز دینار و هرگونه ای بیش وکم
#
#
# input sentence:
# برفتند شادان ازان مرز وبوم
# model output:
# که با او به خون اندر جهان ناامید
# target sentence:
# به نزدیک قیصر ز ایران بروم
#
#
# input sentence:
# همه مهتران خواندند آفرین
# model output:
# که ای شاه را بیشتر
# target sentence:
# بران پر هنر شهریار زمین
#
#
# input sentence:
# کنون داستان کهن نو کنیم
# model output:
# که با او به گیتی نبود کنیم
# target sentence:
# سخنهای شیرین و خسرو کنیم
#
#
# input sentence:
# کهن گشته این نامهٔ باستان
# model output:
# که با او به فرمان او در افگند بن
# target sentence:
# ز گفتار و کردار آن راستان
#
#
# input sentence:
# همی نوکنم گفته ها زین سخن
# model output:
# که با او به خوبی افگند بن
# target sentence:
# ز گفتار بیدار مرد کهن
#
#
# input sentence:
# بود بیست شش بار بیور هزار
# model output:
# که با او به گیتی افروز شمار
# target sentence:
# سخنهای شایسته و غمگسار
#
#
# input sentence:
# نبیند کسی نامهٔ پارسی
# model output:
# که با او به گیتی افروز زهر
# target sentence:
# نوشته به ابیات صدبار سی
#
#
# input sentence:
# اگر بازجویی درو بیت بد
# model output:
# که با من به خوبی کشنده زینهار
# target sentence:
# همانا که کم باشد از پانصد
#
#
# input sentence:
# چنین شهریاری و بخشنده ای
# model output:
# که با من به خوبی برو روزگار
# target sentence:
# به گیتی ز شاهان درخشنده ای
#
#
# input sentence:
# نکرد اندرین داستانها نگاه
# model output:
# که با تو مبادا که چندان سپاه
# target sentence:
# ز بدگوی و بخت بد آمد گناه
#
#
# input sentence:
# حسد کرد بدگوی در کار من
# model output:
# به پیش اندرون انجمن یادگار
# target sentence:
# تبه شد بر شاه بازار من
#
#
# input sentence:
# چو سالار شاه این سخنهای نغز
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# بخواند ببیند به پاکیزه نغز
#
#
# input sentence:
# ز گنجش من ایدر شوم شادمان
# model output:
# که با من به خوبی کشنده گمان
# target sentence:
# کزو دور بادا بد بدگمان
#
#
# input sentence:
# وزان پس کند یاد بر شهریار
# model output:
# به پیش اندرون نیزه ور سوار
# target sentence:
# مگر تخم رنج من آید ببار
#
#
# input sentence:
# که جاوید باد افسر و تخت اوی
# model output:
# که با تو مبادا که آید بروی
# target sentence:
# ز خورشید تابنده تر بخت اوی
#
#
# input sentence:
# چنین گفت داننده دهقان پیر
# model output:
# که این را بها این سخن یادگیر
# target sentence:
# که دانش بود مرد را دستگیر
#
#
# input sentence:
# غم و شادمانی بباید کشید
# model output:
# که با من به خوبی کشنده رسید
# target sentence:
# ز هر شور و تلخی بباید چشید
#
#
# input sentence:
# جوانان داننده و باگهر
# model output:
# که با من به گیتی به دشمن دست
# target sentence:
# نگیرند بی آزمایش هنر
#
#
# input sentence:
# چو پرویز ناباک بود و جوان
# model output:
# که با او به نیکی دهش بر گذر
# target sentence:
# پدر زنده و پور چون پهلوان
#
#
# input sentence:
# ورا در زمین دوست شیرین بدی
# model output:
# که با او به گیتی به روم بدی
# target sentence:
# برو بر چو روشن جهان بین بدی
#
#
# input sentence:
# پسندش نبودی جزو در جهان
# model output:
# که با او به یزدان نیکی نهان
# target sentence:
# ز خوبان وز دختران مهان
#
#
# input sentence:
# ز شیرن جدا بود یک روزگار
# model output:
# که با او به گیتی همی یادگار
# target sentence:
# بدان گه که بد در جهان شهریار
#
#
# input sentence:
# بگرد جهان در بی آرام بود
# model output:
# که با او به یزدان شوند بود
# target sentence:
# که کارش همه رزم بهرام بود
#
#
# input sentence:
# چو خسرو به پردخت چندی به مهر
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# شب و روز گریان بدی خوب چهر
#
#
# input sentence:
# چنان بد که یک روز پرویز شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# همی آرزو کرد نخچیرگاه
#
#
# input sentence:
# بیاراست برسان شاهنشهان
# model output:
# که با او به گیتی همی گشت
# target sentence:
# که بوند ازو پیشتر در جهان
#
#
# input sentence:
# چو بالای سیصد به زرین ستام
# model output:
# به پیش اندرون ساخته تنگ
# target sentence:
# ببردند با خسرو نیک نام
#
#
# input sentence:
# هزار و صد و شست خسرو پرست
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# پیاده همی رفت ژوپین بدست
#
#
# input sentence:
# هزار و چهل چوب و شمشیر داشت
# model output:
# به پیش اندرون ساخته داشت راز
# target sentence:
# که دیبای در بر زره زیر داشت
#
#
# input sentence:
# پس اندر بدی پانصد بازدار
# model output:
# به پیش اندرون ساخته چند دست
# target sentence:
# هم از واشه و چرغ و شاهین کار
#
#
# input sentence:
# ازان پس برفتند سیصد سوار
# model output:
# که گفتی برو بر بسی دار
# target sentence:
# پس بازداران با یوزدار
#
#
# input sentence:
# به زنجیر هفتاد شیروپلنگ
# model output:
# به پیش سپاه اندر آرم سرش
# target sentence:
# به دیبای چین اندرون بسته تنگ
# input sentence:
# پلنگان و شیران آموخته
# model output:
# که با او به گیتی به هامون برند
# target sentence:
# به زنجیر زرین دهن دوخته
#
#
# input sentence:
# قلاده بزر بسته صد بود سگ
# model output:
# که با او به یزدان نیکی گمان
# target sentence:
# که دردشت آهو گرفتی بتگ
#
#
# input sentence:
# پس اندر ز رامشگران دوهزار
# model output:
# به پیش اندرون ساخته بیش و کم
# target sentence:
# همه ساخته رود روز شکار
#
#
# input sentence:
# به زیر اندرون هریکی اشتری
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# به سر برنهاده ز زر افسری
#
#
# input sentence:
# ز کرسی و خرگاه و پرده سرای
# model output:
# به پیش اندرون ساخته رهنمای
# target sentence:
# همان خیمه و آخر چارپای
#
#
# input sentence:
# شتر بود پیش اندرون پانصد
# model output:
# به پیش اندرون ساخته چند
# target sentence:
# همه کرده آن بزم را نامزد
#
#
# input sentence:
# ز شاهان برنای سیصد سوار
# model output:
# به پیش اندرون نیزه دار
# target sentence:
# همی راند با نامور شهریار
#
#
# input sentence:
# ابا یاره و طوق و زرین کمر
# model output:
# به پیش اندرون ساخته چند پارسی
# target sentence:
# بهر مهره ای در نشانده گهر
#
#
# input sentence:
# دوصد برده تامجمر افروختند
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# برو عود و عنبر همی سوختند
#
#
# input sentence:
# دوصد مرد برنای فرمانبران
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# ابا هریکی نرگس و زعفران
#
#
# input sentence:
# همه پیش بردند تا باد بوی
# model output:
# به پیش اندرون ساخته بیش و گوی
# target sentence:
# چو آید ز هر سو رساند بدوی
#
#
# input sentence:
# همه پیش آنکس که با بوی خوش
# model output:
# به پیش اندرون ساخته لشکری
# target sentence:
# همی رفت با مشک صد آبکش
#
#
# input sentence:
# که تا ناورد ناگهان گرد باد
# model output:
# به پیش اندرون ساخته کرد یاد
# target sentence:
# نشاند بران شاه فرخ نژاد
#
#
# input sentence:
# چو بشنید شیرین که آمد سپاه
# model output:
# به پیش اندرون ساخته رزمگاه
# target sentence:
# به پیش سپاه آن جهاندار شاه
#
#
# input sentence:
# یکی زرد پیراهن مشک بوی
# model output:
# که با او به گیتی افروز شد
# target sentence:
# بپوشید و گلنارگون کرد روی
#
#
# input sentence:
# یکی از برش سرخ دیبای روم
# model output:
# به پیش اندرون ساخته مرز و بوم
# target sentence:
# همه پیکرش گوهر و زر بوم
#
#
# input sentence:
# به سر برنهاد افسر خسروی
# model output:
# به پیش اندرون ساخته بدم
# target sentence:
# نگارش همه پیکر پهلوای
#
#
# input sentence:
# از ایوان خسرو برآمد ببام
# model output:
# که با او به باغ آمد به باغ
# target sentence:
# به روز جوانی نبد شادکام
#
#
# input sentence:
# همی بود تاخسرو آنجا رسید
# model output:
# به پیش اندرون ساخته برگزید
# target sentence:
# سرشکش ز مژگان برخ برچکید
#
#
# input sentence:
# چو روی ورا دید برپای خاست
# model output:
# به پیش اندرون ساخته راست موی
# target sentence:
# به پرویز بنمود بالای راست
#
#
# input sentence:
# زبان کرد گویا بشیرین سخن
# model output:
# که با او به خوبی افگند بن
# target sentence:
# همی گفت زان روزگار کهن
#
#
# input sentence:
# به نرگس گل و ارغوان را بشست
# model output:
# که با او به گیتی همی جست
# target sentence:
# که بیمار بد نرگس وگل درست
#
#
# input sentence:
# بدان آبداری و آن نیکوی
# model output:
# به پیش اندرون ساخته ور
# target sentence:
# زبان تیز بگشاد برپهلوی
#
#
# input sentence:
# که تهما هژب را سپهبدتنا
# model output:
# به پیش سپاه آن سخن پیش
# target sentence:
# خجسته کیاگرد شیراوژنا
#
#
# input sentence:
# کجا آن همه مهر و خونین سرشک
# model output:
# به پیش سپاه اندر آرم پزشک
# target sentence:
# که دیدار شیرین بد او را پزشک
#
#
# input sentence:
# کجا آن همه روز کردن به شب
# model output:
# به پیش اندرون ساخته لب
# target sentence:
# دل و دیده گریان و خندان دو لب
#
#
# input sentence:
# کجا آن همه بند و پیوندما
# model output:
# که با او به گیتی به نیکی شناس
# target sentence:
# کجا آن همه عهد و سوگند ما
#
#
# input sentence:
# همی گفت وز دیده خوناب زرد
# model output:
# به پیش اندرون نیزه ور لاژورد
# target sentence:
# همی ریخت برجامهٔ لاژورد
#
#
# input sentence:
# به چشم اندر آورد زو خسرو آب
# model output:
# که با او به گیتی همی آفتاب
# target sentence:
# به زردی رخش گشت چون آفتاب
#
#
# input sentence:
# فرستاد بالای زرین ستام
# model output:
# که با او به پیش اندرش روم شوم
# target sentence:
# ز رومی چهل خادم نیک نام
#
#
# input sentence:
# که او را به مشکوی زرین برند
# model output:
# که با او به گیتی به هامون برند
# target sentence:
# سوی خانهٔ گوهر آگین برند
#
#
# input sentence:
# ازان جایگه شد به دشت شکار
# model output:
# که گفتی برو بر بسی دار
# target sentence:
# ابا باده ورود و با میگسار
#
#
# input sentence:
# چو از کوه وز دشت برداشت بهر
# model output:
# به پیش اندرون ساخته هفت
# target sentence:
# همی رفت شادی کنان سوی شهر
#
#
# input sentence:
# ببستند آذین بشهر و به راه
# model output:
# به پیش اندرون ساخته شاه شاه
# target sentence:
# که شاه آمد از دشت نخچیرگاه
#
#
# input sentence:
# ز نالیدن بوق و بانگ سرود
# model output:
# به پیش اندرون ساخته رود
# target sentence:
# هوا گشت ز آواز بی تار و پود
#
#
# input sentence:
# چنان خسروی برز و شاخ بلند
# model output:
# که با او به یزدان نجست
# target sentence:
# ز دشت اندر آمد به کاخ بلند
#
#
# input sentence:
# ز مشکوی شیرین بیامد برش
# model output:
# به پیش اندرون ساخته لشکری
# target sentence:
# ببوسید پای و زمین و برش
#
#
# input sentence:
# به موبد چنین گفت شاه آن زمان
# model output:
# که این را به خوبی گمان را گمان
# target sentence:
# که بر ما مبر جز به نیکی گمان
#
#
# input sentence:
# مرین خوب رخ را به خسرو دهید
# model output:
# که با من به خوبی زمانی سپاه
# target sentence:
# جهان را بدین مژدهٔ نو دهید
#
#
# input sentence:
# مر او را به آیین پیشی بخواست
# model output:
# که با او به گیتی افروز کام
# target sentence:
# که آن رسم و آیین بد آنگاه راست
#
#
# input sentence:
# چو آگاهی آمد ز خسرو به راه
# model output:
# که گفتی به نزدیک شاه سپاه
# target sentence:
# به نزد بزرگان و نزد سپاه
#
#
# input sentence:
# که شیرین به مشکوی خسرو شدست
# model output:
# که با او به یزدان نیکی شدست
# target sentence:
# کهن بود کار جهان نوشدست
#
#
# input sentence:
# همه شهر زان کار غمگین شدند
# model output:
# به پیش سپاه اندر میان شدند
# target sentence:
# پر اندیشه و درد و نفرین شدند
#
#
# input sentence:
# نرفتند نزدیک خسرو سه روز
# model output:
# که با او به گیتی فروز
# target sentence:
# چهارم چوب فروخت گیتی فروز
#
#
# input sentence:
# فرستاد خسرو مهان را بخواند
# model output:
# که با او به پیش اندرون انجمن
# target sentence:
# بگاه گران مایگان برنشاند
#
#
# input sentence:
# بدیشان چنین گفت کاین روز چند
# model output:
# که با من به خوبی کشنده گزند
# target sentence:
# ندیدم شما را شدم مستمند
#
#
# input sentence:
# بیازردم از بهر آزارتان
# model output:
# که با من به خوبی کشنده شمار
# target sentence:
# پراندیشه گشتم ز تیمارتان
#
#
# input sentence:
# همی گفت و پاسخ نداد ایچ کس
# model output:
# که این را به خوبی کشنده بس
# target sentence:
# ز گفتن زبانها ببستند بس
#
#
# input sentence:
# هرآنکس که او داشت آزار و خشم
# model output:
# که با من به نیکی دهش یاد
# target sentence:
# یکایک به موبد نمودند چشم
#
#
# input sentence:
# چو موبد چنان دید برپای خاست
# model output:
# که با او به گیتی افروز کام
# target sentence:
# به خسرو چنین گفت کای راد وراست
#
#
# input sentence:
# به روز جوانی شدی شهریار
# model output:
# که با من به خوبی نیاید به کار
# target sentence:
# بسی نیک و بد دیدی از روزگار
#
#
# input sentence:
# شنیدی بسی نیک و بد در جهان
# model output:
# که با من به نیکی دهش آشکار
# target sentence:
# ز کار بزرگان و کار مهان
#
#
# input sentence:
# کنون تخمهٔ مهتر آلوده شد
# model output:
# که با او به گیتی کسی را شد
# target sentence:
# بزرگی ازین تخمهٔ پالوده شد
#
#
# input sentence:
# پدر پاک و مادر بود بی هنر
# model output:
# که با من به خوبی کشنده گذر
# target sentence:
# چنان دان که پاکی نیاید ببر
#
#
# input sentence:
# ز کژی نجوید کسی راستی
# model output:
# که با من به خوبی کشنده کاستی
# target sentence:
# که از راستی برکنی کاستی
#
#
# input sentence:
# دل ما غمی شد ز دیو سترگ
# model output:
# به پیش اندرون ساخته بزرگ
# target sentence:
# که شد یار با شهریار بزرگ
#
#
# input sentence:
# به ایران اگر زن نبودی جزین
# model output:
# که با او به یزدان مشو را زمین
# target sentence:
# که خسرو بدو خواندی آفرین
#
#
# input sentence:
# نبودی چو شیرین به مشکوی او
# model output:
# که با او به گیتی او را نیاز
# target sentence:
# بهر جای روشن بدی روی او
#
#
# input sentence:
# نیاکانت آن دانشی راستان
# model output:
# که با او به یزدان نیکی خرد
# target sentence:
# نکردند یاد از چنین داستان
#
#
# input sentence:
# چوگشت آن سخنهای موبد دراز
# model output:
# که با او به گیتی همی باز
# target sentence:
# شهنشاه پاسخ نداد ایچ باز
#
#
# input sentence:
# چنین گفت موبد که فردا پگاه
# model output:
# به پیش سپاه اندر آرم سپاه
# target sentence:
# بیاییم یکسر بدین بارگاه
#
#
# input sentence:
# مگر پاسخ شاه یابیم باز
# model output:
# که ای شاه چندان زمانی دراز
# target sentence:
# که امروزمان شد سخنها دراز
#
#
# input sentence:
# دگر روز شبگیر برخاستند
# model output:
# به پیش اندرش بیاراستند
# target sentence:
# همه بندگی را بیاراستند
#
#
# input sentence:
# یکی گفت موبد ندانست گفت
# model output:
# که این را به خوبی زمانی نهفت
# target sentence:
# دگر گفت کان با خرد بود جفت
#
#
# input sentence:
# سیوم گفت که امروز پاسخ دهد
# model output:
# که با من به خوبی کشنده دهد
# target sentence:
# سزد زو که آواز فرخ نهد
#
#
# input sentence:
# همه موبدان برگرفتند راه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# خرامان برفتند نزدیک شاه
#
#
# input sentence:
# بزرگان گزیدند جای نشست
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# بیامد یکی مرد تشتی بدست
#
#
# input sentence:
# چو خورشید رخشنده پالوده گشت
# model output:
# به پیش اندرون ساخته گشت
# target sentence:
# یکایک بران مهتران برگذشت
#
#
# input sentence:
# بتشت اندرون ریختش خون گرم
# model output:
# به پیش اندرش بر سرش نرم
# target sentence:
# چو نزدیک شد تشت بنهاد نرم
#
#
# input sentence:
# از آن تشت هرکس بپیچید روی
# model output:
# به پیش اندرون ساخته جنگجوی
# target sentence:
# همه انجمن گشت پر گفت و گوی
#
#
# input sentence:
# همی کرد هر کس به خسرو نگاه
# model output:
# که با او به یزدان مشو را نگاه
# target sentence:
# همه انجمن خیره از بیم شاه
#
#
# input sentence:
# به ایرانیان گفت کاین خون کیست
# model output:
# که با من به خوبی گریست
# target sentence:
# نهاده بتشت اندر از بهر چیست
#
#
# input sentence:
# بدو گفت موبد که خون پلید
# model output:
# که با من به گیتی به هامون رسید
# target sentence:
# کزو دشمنش گشت هرکش بدید
#
#
# input sentence:
# چوموبد چنین گفت برداشتش
# model output:
# که این را به خوبی چنو زین شمار
# target sentence:
# همه دست بردست بگذاشتش
#
#
# input sentence:
# ز خون تشت پر مایه کردند پاک
# model output:
# که با او به یزدان نیکی شناس
# target sentence:
# ببستند روشن به آب و به خاک
#
#
# input sentence:
# چو روشن شد و پاک تشت پلید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# بکرد آنک او شسته بد پرنبید
#
#
# input sentence:
# بمی بر پراگند مشک وگلاب
# model output:
# به پیش اندرون ساخته آفتاب
# target sentence:
# شد آن تشت بی رنگ چون آفتاب
#
#
# input sentence:
# ز شیرین بران تشت بد رهنمون
# model output:
# که ای شاه را دست او را همی
# target sentence:
# که آغاز چون بود و فرجام چون
#
#
# input sentence:
# به موبد چنین گفت خسرو که تشت
# model output:
# که ای شاه را نیست ننگ و نبرد
# target sentence:
# همانا بد این گر دگرگونه گشت
#
#
# input sentence:
# بدو گفت موبد که نوشه بدی
# model output:
# به پیش سپاه اندر آرم بدی
# target sentence:
# پدیدار شد نیکوی از بدی
#
#
# input sentence:
# بفرمان ز دوزخ توکردی بهشت
# model output:
# به پیش سپاه اندر آید به کار
# target sentence:
# همان خوب کردی تو کردار زشت
#
#
# input sentence:
# چنین گفت خسرو که شیرین بشهر
# model output:
# که این را به خوبی ورا در مه
# target sentence:
# چنان بد که آن بی منش تشت زهر
#
#
# input sentence:
# کنون تشت می شد به مشکوی ما
# model output:
# که با او به یزدان نیکی دهش
# target sentence:
# برین گونه پربو شد ازبوی ما
#
#
# input sentence:
# ز من گشت بدنام شیرین نخست
# model output:
# به پیش سپاه اندر آرم بشست
# target sentence:
# ز پرمایگان نامداری نجست
#
#
# input sentence:
# همه مهتران خواندند آفرین
# model output:
# که ای شاه را بیشتر
# target sentence:
# که بی تاج وتختت مبادا زمین
#
#
# input sentence:
# بهی آن فزاید که تو به کنی
# model output:
# که با من به گیتی همی تافته
# target sentence:
# مه آن شد بگیتی که تومه کنی
#
#
# input sentence:
# که هم شاه وهم موبد وهم ردی
# model output:
# که با او به گیتی به روم نیست
# target sentence:
# مگر بر زمین سایهٔ ایزدی
#
#
# input sentence:
# ازان پس فزون شد بزرگی شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# که خورشید شد آن کجا بود ماه
#
#
# input sentence:
# همه روز با دخت قیصر بدی
# model output:
# به پیش اندرون ساخته بدی
# target sentence:
# همو بر شبستانش مهتر بدی
#
#
# input sentence:
# ز مریم همی بود شیرین بدرد
# model output:
# که با او به گیتی همی خورد
# target sentence:
# همیشه ز رشکش دو رخساره زرد
#
#
# input sentence:
# به فرجام شیرین ورا زهر داد
# model output:
# به پیش اندرون ساخته یاد کرد
# target sentence:
# شد آن نامور دخت قیصرنژاد
#
#
# input sentence:
# ازان چاره آگه نبد هیچ کس
# model output:
# که با او به گیتی همی بس
# target sentence:
# که او داشت آن راز تنها و بس
#
#
# input sentence:
# چو سالی برآمد که مریم بمرد
# model output:
# به پیش اندرون ساخته باز
# target sentence:
# شبستان زرین به شیرین سپرد
#
#
# input sentence:
# چو شیرویه را سال شد بر دو هشت
# model output:
# به پیش اندرون ساخته آفتاب
# target sentence:
# به بالا زسی سالگان برگذشت
#
#
# input sentence:
# بیاورد فرزانگان را پدر
# model output:
# که با او به آرام گفتی سرش
# target sentence:
# بدان تا شود نامور پر هنر
#
#
# input sentence:
# همی داشت موبد مر او را نگاه
# model output:
# که با او به پیش سپاه سپاه
# target sentence:
# شب و روز شادان به فرمان شاه
#
#
# input sentence:
# چنان بد که یک روز موبد ز تخت
# model output:
# به پیش سپاه آن خسروانی درخت
# target sentence:
# بیامد به نزدیک آن نیک بخت
#
#
# input sentence:
# چو آمد به نزدیک شیرویه باز
# model output:
# به پیش اندرون ساخته راز
# target sentence:
# همیشه به بازیش بودی نیاز
#
#
# input sentence:
# یکی دفتری دید پیش اندرش
# model output:
# که با او به گیتی افروز مهر
# target sentence:
# نوشته کلیله بران دفترش
#
#
# input sentence:
# بدست چپ آن جوان سترگ
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# بریده یکی خشک چنگال گرگ
#
#
# input sentence:
# سروی سر گاومیشی براست
# model output:
# به پیش اندرون ساخته بر پیلان ور
# target sentence:
# همی این بران بر زدی چونک خواست
#
#
# input sentence:
# غمی شد دل موبد از کاراوی
# model output:
# که با او به گیتی افروز شد
# target sentence:
# ز بازی و بیهوده کردار اوی
#
#
# input sentence:
# به فالش بد آمد هم آن چنگ گرگ
# model output:
# به پیش اندرون ساخته پیش گرگ
# target sentence:
# شخ گاو و رای جوان سترگ
#
#
# input sentence:
# ز کار زمانه غمی گشت سخت
# model output:
# که با او به یزدان مشو تخت بخت
# target sentence:
# ازان برمنش کودک شور بخت
#
#
# input sentence:
# کجا طالع زادنش دیده بود
# model output:
# که با او به یزدان کسی را بود
# target sentence:
# ز دستور وگنجور بشنیده بود
#
#
# input sentence:
# سوی موبد موبد آمد بگفت
# model output:
# که ای شاه را یار او را درود
# target sentence:
# که بازیست باآن گرانمایه جفت
#
#
# input sentence:
# بشد زود موبد بگفت آن به شاه
# model output:
# که ای شاه را پیش سپاه
# target sentence:
# همی داشت خسرو مر او را نگاه
#
#
# input sentence:
# ز فرزند رنگ رخش زرد شد
# model output:
# به پیش اندرون ساخته پیشه شد
# target sentence:
# ز کار زمانه پراز درد شد
#
#
# input sentence:
# ز گفتار مرد ستاره شمر
# model output:
# به پیش سپاه اندر آمد بباد
# target sentence:
# دلش بود پر درد و پیچان جگر
#
#
# input sentence:
# همی گفت تا کردگار سپهر
# model output:
# که با من به خوبی کشنده مهر
# target sentence:
# چگونه نماید بدین کرده چهر
#
#
# input sentence:
# چو بر پادشاهیش بیست وسه سال
# model output:
# به پیش سپاه اندر آمد بباد
# target sentence:
# گذر کرد شیرویه به فراخت یال
#
#
# input sentence:
# بیازرد زو شهریار بزرگ
# model output:
# که با او به گیتی افروز گرگ
# target sentence:
# که کودک جوان بود و گشته سترگ
#
#
# input sentence:
# پر از درد شد جان خندان اوی
# model output:
# به پیش اندرون ساخته جنگجوی
# target sentence:
# وز ایوان او کرد زندان اوی
#
#
# input sentence:
# هم آن را که پیوستهٔ اوبدند
# model output:
# که با او به یزدان مشو را نماید
# target sentence:
# گه رای جستن براو شدند
# input sentence:
# بسی دیگر از مهتر و کهتران
# model output:
# که با او به گیتی افروز بیرون برند
# target sentence:
# که بودند با او ببندگران
#
#
# input sentence:
# همی برگرفتند زیشان شمار
# model output:
# که با او به گیتی همی یادگار
# target sentence:
# که پرسه فزون آمد از سه هزار
#
#
# input sentence:
# همه کاخها رایک اندر دگر
# model output:
# به پیش اندرون ساخته چند هفت
# target sentence:
# برید آنک بد شاه را کارگر
#
#
# input sentence:
# ز پوشیدنیها و از خوردنی
# model output:
# که با او به یزدان نیکی گمان
# target sentence:
# ز بخشیدنی هم ز گستردنی
#
#
# input sentence:
# به ایوانهاشان بیاراستند
# model output:
# به پیش اندرش یاره و بوی
# target sentence:
# پرستنده و بندگان خواستند
#
#
# input sentence:
# همان می فرستاد و رامشگران
# model output:
# که با او به خون اندر آمد زیان
# target sentence:
# همه کاخ دینار بد بی کران
#
#
# input sentence:
# به هنگامشان رامش و خورد بود
# model output:
# که با من به خون اندر فزایش بود
# target sentence:
# نگهبان ایشان چهل مرد بود
#
#
# input sentence:
# کنون داستان گوی در داستان
# model output:
# که با او به نیکی دهش کرد
# target sentence:
# ازان یک دل ویک زبان راستان
#
#
# input sentence:
# ز تختی که خوانی ورا طاق دیس
# model output:
# که با او به گیتی افروز شد
# target sentence:
# که بنهاد پرویز دراسپریس
#
#
# input sentence:
# سرمایهٔ آن ز ضحاک بود
# model output:
# که با من به خوبی چنو بود
# target sentence:
# که ناپارسا بود و ناپاک بود
#
#
# input sentence:
# بگاهی که رفت آفریدون گرد
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# وزان تا زیان نام مردی ببرد
#
#
# input sentence:
# یکی مرد بد در دماوند کوه
# model output:
# که با او به پیش اندرش گروه
# target sentence:
# که شاهش جدا داشتی ازگروه
#
#
# input sentence:
# کجا جهن بر زین بدی نام اوی
# model output:
# به پیش اندرون ساخته پیش اوی
# target sentence:
# رسیده بهر کشوری کام اوی
#
#
# input sentence:
# یکی نامور شاه را تخت ساخت
# model output:
# به پیش اندرون ساخته آفتاب
# target sentence:
# گهر گرد بر گرد او در نشاخت
#
#
# input sentence:
# که شاه آفریدون بدوشاد بود
# model output:
# که با او به یزدان نباید شنود
# target sentence:
# که آن تخت پرمایه آزاد بود
#
#
# input sentence:
# درم داد مر جهن را سی هزار
# model output:
# که با او به گیتی همی بود کار
# target sentence:
# یکی تاج زرین و دو گوشوار
#
#
# input sentence:
# همان عهد ساری و آمل نوشت
# model output:
# که با او به گیتی به نیکی بهشت
# target sentence:
# که بد مرز منشور او چون بهشت
#
#
# input sentence:
# بدانگه که ایران به ایرج رسید
# model output:
# که با او به گیتی او را کلید
# target sentence:
# کزان نامداران وی آمد پدید
#
#
# input sentence:
# جهاندار شاه آفریدون سه چیز
# model output:
# که با او به یزدان نجست
# target sentence:
# بران پادشاهی برافزود نیز
#
#
# input sentence:
# یکی تخت و آن گرزهٔ گاوسار
# model output:
# که با او به گیتی همی بود
# target sentence:
# که ماندست زو در جهان یادگار
#
#
# input sentence:
# سدیگر کجا هفت چشمه گهر
# model output:
# به پیش سپاه اندر آمد سزاوار
# target sentence:
# همی خواندی نام او دادگر
#
#
# input sentence:
# چو ایرج بشد زو بماند این سه چیز
# model output:
# به پیش سپاه اندر آورده نیز
# target sentence:
# همان شاد بد زو منوچهر نیز
#
#
# input sentence:
# هر آنکس که او تاج شاهی به سود
# model output:
# که با او به یزدان نیکی دهش
# target sentence:
# بران تخت چیزی همی برفزود
#
#
# input sentence:
# چو آمد به کیخسرو نیک بخت
# model output:
# به پیش اندرون ساخته تاج و تخت
# target sentence:
# فراوان بیفزود بالای تخت
#
#
# input sentence:
# برین هم نشان تا به لهراسپ شد
# model output:
# به پیش اندرون ساخته پیشه شد
# target sentence:
# وزو همچنان تا به گشتاسپ شد
#
#
# input sentence:
# چو گشتاسپ آن تخت رادید گفت
# model output:
# که این را به خوبی نشاید نهفت
# target sentence:
# که کار بزرگان نشاید نهفت
#
#
# input sentence:
# به جاماسپ گفت ای گرانمایه مرد
# model output:
# که با من به خوبی زمانی نبرد
# target sentence:
# فزونی چه داری به دین کارکرد
#
#
# input sentence:
# یکایک ببین تا چه خواهی فزود
# model output:
# که با من به خوبی زمانی دراز
# target sentence:
# پس از مرگ ما راکه خواهد ستود
#
#
# input sentence:
# چو جا ماسپ آن تخت رابنگرید
# model output:
# به پیش سپاه اندر آرم سرش
# target sentence:
# بدید از در گنج دانش کلید
#
#
# input sentence:
# برو بر شمار سپهر بلند
# model output:
# که با من به خون اندر میان
# target sentence:
# همی کرد پیدا چه و چون وچند
#
#
# input sentence:
# ز کیوان همه نقشها تا به ماه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# بران تخت کرد او به فرمان شاه
#
#
# input sentence:
# چنین تابگاه سکندر رسید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# ز شاهان هر آنکس که آن گاه دید
#
#
# input sentence:
# همی برفزودی برو چند چیز
# model output:
# به پیش سپاه آن کیانی بدند
# target sentence:
# ز زر و ز سیم و ز عاج و ز شیز
#
#
# input sentence:
# مر آن را سکندر همه پاره کرد
# model output:
# به پیش اندرون ساخته کرد
# target sentence:
# ز بی دانشی کار یکباره کرد
#
#
# input sentence:
# بسی از بزرگان نهان داشتند
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# همی دست بر دست بگذاشتند
#
#
# input sentence:
# بدین گونه بد تا سر اردشیر
# model output:
# به پیش سپاه اندر آرم آسان
# target sentence:
# کجا گشته بد نام آن تخت پیر
#
#
# input sentence:
# ازان تخت جایی نشانی نیافت
# model output:
# به پیش اندرون ساخته بر زیان
# target sentence:
# بران آرزو سوی دیگر شتاف
#
#
# input sentence:
# بمرد او و آن تخ ازو بازماند
# model output:
# به پیش اندرون ساخته پیش دبیر
# target sentence:
# ازان پس که کام بزرگی براند
#
#
# input sentence:
# بدین گونه بد تا به پرویزشاه
# model output:
# که با او به یزدان سزد آفرین
# target sentence:
# رسید آن گرامی سزاوار گاه
#
#
# input sentence:
# ز هر کشوری مهتران رابخواند
# model output:
# که با او به گیتی به کیوان رسید
# target sentence:
# وزان تخت چندی سخنها براند
#
#
# input sentence:
# ازیشان فراوان شکسته بیافت
# model output:
# که با او به گیتی به گیتی فروز
# target sentence:
# به شادی سوی گرد کردن شتافت
#
#
# input sentence:
# بیاورد پس تخت شاه اردشیر
# model output:
# به پیش سپاه اندر آمد فراز
# target sentence:
# ز ایران هر آنکس که بد تیزویر
#
#
# input sentence:
# بهم بر زدند آن سزاوار تخت
# model output:
# که با او به یزدان دانا درخت
# target sentence:
# به هنگام آن شاه پیروزبخت
#
#
# input sentence:
# ورا درگر آمد ز روم و ز چین
# model output:
# به پیش اندرون ساخته زمین
# target sentence:
# ز مکران و بغداد و ایران زمین
#
#
# input sentence:
# هزار و صد و بیست استاد بود
# model output:
# که با او به یزدان نیکی بود
# target sentence:
# که کردار آن تختشان یادبود
#
#
# input sentence:
# که او را بنا شاه گشتاسپ کرد
# model output:
# به پیش اندرون ساخته کرد
# target sentence:
# برای و به تدبیر جاماسپ کرد
#
#
# input sentence:
# ابا هریکی مرد شاگرد سی
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# ز رومی و بغدادی و پارسی
#
#
# input sentence:
# نفرمود تا یک زمان دم زدند
# model output:
# به پیش سپاه اندر آرم زدند
# target sentence:
# بدو سال تا تخت برهم زدند
#
#
# input sentence:
# چوبر پای کردند تخت بلند
# model output:
# به پیش اندرون ساخته چند اسپ
# target sentence:
# درخشنده شد روی بخت بلند
#
#
# input sentence:
# برش بود بالای صد شاه رش
# model output:
# به پیش سپاه اندر آمد سرش
# target sentence:
# چو هفتاد رش برنهی ازبرش
#
#
# input sentence:
# صد و بیست رش نیز پهناش بود
# model output:
# که با او به پیش اندرش تار بود
# target sentence:
# که پهناش کمتر ز بالاش بود
#
#
# input sentence:
# بلندیش پنجاه و صد شاه رش
# model output:
# که با او به یزدان شوند
# target sentence:
# چنان بد که بر ابر سودی سرش
#
#
# input sentence:
# همان شاه رش هر رشی زو سه رش
# model output:
# به پیش سپاه اندر آمد سرش
# target sentence:
# کزان سر بدیدی بن کشورش
#
#
# input sentence:
# بسی روز در ماه هر بامداد
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# یکی فرش بودی به دیگر نهاد
#
#
# input sentence:
# همان تخت به دوازده لخت بود
# model output:
# به پیش سپاه اندر آرم نمود
# target sentence:
# جهانی سراسر همه تخت بود
#
#
# input sentence:
# بروبش زرین صد و چل هزار
# model output:
# که با او به گیتی همی بود کار
# target sentence:
# ز پیروزه بر زر کرده نگار
#
#
# input sentence:
# همه نقرهٔ خام بد میخ بش
# model output:
# که با او به گیتی همی داد کس
# target sentence:
# یکی صد به مثقال با شست و شش
#
#
# input sentence:
# چو اندر بره خور نهادی چراغ
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# پسش دشت بودی و در پیش باغ
#
#
# input sentence:
# چوخورشید درشیرگشتی درشت
# model output:
# که با او به یزدان سزد گر زمان
# target sentence:
# مرآن تخت را سوی او بود پشت
#
#
# input sentence:
# چو هنگامهٔ تیر ماه آمدی
# model output:
# به پیش سپاه اندر آمد نیاز
# target sentence:
# گه میوه و جشنگاه آمدی
#
#
# input sentence:
# سوی میوه و باغ بودیش روی
# model output:
# که با او به گیتی افروز گفت
# target sentence:
# بدان تا بیابد زهرمیوه بوی
#
#
# input sentence:
# زمستان که بودی گه با دونم
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# بر آن تخت برکس نبودی دژم
#
#
# input sentence:
# همه طاقها بود بسته ازار
# model output:
# به پیش اندرون ساخته چند راست
# target sentence:
# ز خز و سمور از در شهریار
#
#
# input sentence:
# همان گوی زرین و سیمین هزار
# model output:
# که با او به گیتی همی کارزار
# target sentence:
# بر آتش همی تافتی جامه دار
#
#
# input sentence:
# به مثقال ازان هریکی پانصد
# model output:
# به پیش اندرون ساخته بر سپاه
# target sentence:
# کز آتش شدی سرخ همچون به سد
#
#
# input sentence:
# یکی نیمه زو اندر آتش بدی
# model output:
# به پیش اندرون ساخته بدی
# target sentence:
# دگر پیش گردان سرکش بدی
#
#
# input sentence:
# شمار ستاره ده و دو و هفت
# model output:
# به پیش سپاه اندر آمد زیان
# target sentence:
# همان ماه تابان ببرجی که رفت
#
#
# input sentence:
# چه زو ایستاده چه مانده بجا
# model output:
# که با من به گیتی به گیتی فروز
# target sentence:
# بدیدی به چشم سر اخترگرا
# input sentence:
# ز شب نیز دیدی که چندی گذشت
# model output:
# به پیش اندرون ساخته دشت
# target sentence:
# سپهر از بر خاک بر چند گشت
#
#
# input sentence:
# ازان تختها چند زرین بدی
# model output:
# به پیش اندرون ساخته بدی
# target sentence:
# چه مایه ز زر گوهر آگین بدی
#
#
# input sentence:
# شمارش ندانست کردن کسی
# model output:
# که با او به گیتی بسی شادکام
# target sentence:
# اگر چند بودیش دانش بسی
#
#
# input sentence:
# هرآن گوهری کش بهاخوار بود
# model output:
# که با او به یزدان نیکی شنود
# target sentence:
# کمابیش هفتاد دینار بود
#
#
# input sentence:
# بسی نیز بگذشت بر هفتصد
# model output:
# که با او به گیتی همی رای جوی
# target sentence:
# همی گیر زین گونه از نیک و بد
#
#
# input sentence:
# بسی سرخ گوگرد بدکش بها
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# ندانست کس مایه و منتها
#
#
# input sentence:
# که روشن بدی در شب تیره چهر
# model output:
# که با او به خون اندر میان سپاه
# ...
# که با او به فرمان او تاج شاه
# target sentence:
# به فرمان او بر نشینم به گاه
#
#
# input sentence:
# بدین چاره ده بند بد را فروغ
# model output:
# که با من به خوبی کشنده دروغ
# target sentence:
# که داند که این راستست از دروغ
#
#
# input sentence:
# چوبشنید ماهوی گفتا که زه
# model output:
# که با من به خوبی کشنده درشت
# target sentence:
# تو دستوری و بر تو بر نیست مه
#
#
# input sentence:
# همه مهتران را ز لشکر بخواند
# model output:
# به پیش اندرون نیزه ور را براند
# target sentence:
# وزین گونه چندین سخنها براند
#
#
# input sentence:
# بدانست لشکر که این نیست راست
# model output:
# که با من به خوبی چنو خواست
# target sentence:
# به شوخی ورا سر بریدن سزاست
#
#
# input sentence:
# یکی پهلوان گفت کاین کار تست
# model output:
# که با من به خوبی بسی بیش و کم
# target sentence:
# سخن گر درستست گر نادرست
#
#
# input sentence:
# چوبشنید بر تخت شاهی نشست
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# به افسون خراسانش آمد بدست
#
#
# input sentence:
# ببخشید روی زمین بر مهان
# model output:
# که با او به گیتی همی کرد
# target sentence:
# منم گفت با مهر شاه جهان
#
#
# input sentence:
# جهان را سراسر به بخشش گرفت
# model output:
# به پیش اندرون بر سرش برگذشت
# target sentence:
# ستاره نظاره برو ای شگفت
#
#
# input sentence:
# به مهتر پسر داد بلخ و هری
# model output:
# که با او به گیتی همی بدی
# target sentence:
# فرستاد بر هر سوی لشکری
#
#
# input sentence:
# بد اندیشگان را همه برکشید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# بدانسان که از گوهر او سزید
#
#
# input sentence:
# بدان را بهرجای سالار کرد
# model output:
# که با او به گیتی به روز نبرد
# target sentence:
# خردمند را سرنگونسارکرد
#
#
# input sentence:
# چو زیراندر آمد سر راستی
# model output:
# به پیش اندرون با کاستی
# target sentence:
# پدید آمد از هر سوی کاستی
#
#
# input sentence:
# چولشکر فراوان شد و خواسته
# model output:
# به پیش اندرون ساخته آراسته
# target sentence:
# دل مرد بی تن شد آراسته
#
#
# input sentence:
# سپه را درم داد و آباد کرد
# model output:
# به پیش سپاه اندر آرم بداد
# target sentence:
# سر دوده خویش پرباد کرد
#
#
# input sentence:
# به آموی شد پهلو پیش رو
# model output:
# که با او به باغ آمد دو اسپ
# target sentence:
# ابا لشکری جنگ سازان نو
#
#
# input sentence:
# طلایه به پیش سپاه اندرون
# model output:
# به پیش اندرون ساخته چند
# target sentence:
# جهان دیده ای نام او گرستون
#
#
# input sentence:
# به شهر بخارا نهادند روی
# model output:
# به پیش اندرون ساخته جنگجوی
# target sentence:
# چنان ساخته لشکری جنگجوی
#
#
# input sentence:
# بدو گفت ما را سمرقند و چاچ
# model output:
# که با من به خوبی کشنده سرش
# target sentence:
# بباید گرفتن بدین مهر و تاج
#
#
# input sentence:
# به فرمان شاه جهان یزدگرد
# model output:
# که با من به خوبی چنو گرد
# target sentence:
# که سالار بد او بر این هفت گرد
#
#
# input sentence:
# ز بیژن بخواهم به شمشیر کین
# model output:
# که با او به یزدان مشو را دین
# target sentence:
# کزو تیره شد بخت ایران زمین
#
#
# input sentence:
# چنین تا به بیژن رسید آگهی
# model output:
# که با او به یزدان مشو فرهی
# target sentence:
# که ماهوی بگرفت تخت مهی
#
#
# input sentence:
# بهر سوی فرستاد مهر و نگین
# model output:
# که با او به گیتی همی کرد
# target sentence:
# همی رام گردد برو بر زمین
#
#
# input sentence:
# کنون سوی جیحون نهادست روی
# model output:
# به پیش اندرون ساخته جنگجوی
# target sentence:
# به پرخاش با لشکری جنگجوی
#
#
# input sentence:
# بپرسید بیژن که تاجش که داد
# model output:
# که با من به خوبی کشنده بسوخت
# target sentence:
# بروکرد گوینده آن کاریاد
#
#
# input sentence:
# بدو گفت برسام کای شهریار
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# چو من بردم از چاچ چندان سوار
#
#
# input sentence:
# بیاوردم از مرو چندان بنه
# model output:
# که با او به گیتی همی شادکام
# target sentence:
# بشد یزدگرد از میان یک تنه
#
#
# input sentence:
# تو را گفته بد تخت زرین اوی
# model output:
# به پیش سپاه اندر آمد بروی
# target sentence:
# همان یارهٔ گوهر آگین اوی
#
#
# input sentence:
# همان گنج و تاجش فرستم به چاج
# model output:
# که با من به خوبی رسد داشت
# target sentence:
# تو را باید اندر جهان تخت عاج
#
#
# input sentence:
# به مرو اندرون رزم کردم سه روز
# model output:
# به پیش اندرون گیتی فروز
# target sentence:
# چهارم چو بفروخت گیتی فروز
# input sentence:
# شدم تنگدل رزم کردم درشت
# model output:
# که با من به خوبی کشنده فروغ
# target sentence:
# جفا پیشه ماهوی بنمود پشت
#
#
# input sentence:
# چو ماهوی گنج خداوند خویش
# model output:
# به پیش سپاه اندر آرم سرش
# target sentence:
# بیاورد بی رنج و بنهاد پیش
#
#
# input sentence:
# چوآگنده شد مرد بی تن به چیز
# model output:
# که با او به یزدان نیکی گمان
# target sentence:
# مرا خود تو گفتی ندیدست نیز
#
#
# input sentence:
# به مرو اندرون بود لشکر دوماه
# model output:
# به پیش اندرون ساخته بر بهی
# target sentence:
# به خوبی نکرد ایچ برمانگاه
#
#
# input sentence:
# بکشت او خداوند را در نهان
# model output:
# که با من به خوبی کشنده مهان
# target sentence:
# چنان پادشاهی بزرگ جهان
#
#
# input sentence:
# سواری که گفتی میان سپاه
# model output:
# که با او به پیش سپاه آمد سپاه
# target sentence:
# همی برگذارد سر از چرخ ماه
#
#
# input sentence:
# ز ترکان کسی پیش گرزش نرفت
# model output:
# که با او به گیتی به خوبی رسید
# target sentence:
# همی زو دل نامداران بگفت
#
#
# input sentence:
# چو او کشته شد پادشاهی گرفت
# model output:
# به پیش اندرون بر گرفت آن شگفت
# target sentence:
# بدین گونه ناپارسایی گرفت
#
#
# input sentence:
# طلایه همی گوید آمد سپاه
# model output:
# که با او به گیتی سزاوار گاه
# target sentence:
# نباید که بر ما بگیرند راه
#
#
# input sentence:
# چو بدخواه جنگی به بالین رسید
# model output:
# که با او به گیتی او را کلید
# target sentence:
# نباید تو را با سپاه آرمید
#
#
# input sentence:
# چنین گل به پالیز شاهان مباد
# model output:
# که با او به گیتی افروز نهاد
# target sentence:
# چو باشد نیاید ز پالیز یاد
#
#
# input sentence:
# چو بشنید بیژن سپه گرد کرد
# model output:
# به پیش اندرون ساخته کرد
# target sentence:
# ز ترکان سواران روز نبرد
#
#
# input sentence:
# ز قجقار باشی بیامد دمان
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# نجست ایچ گونه بره بر زمان
#
#
# input sentence:
# چونزدیک شهر بخارا رسید
# model output:
# که ای شاه را چون شدش دید
# target sentence:
# همه دشت نخشب سپه گسترید
#
#
# input sentence:
# به یاران چنین گفت که اکنون شتاب
# model output:
# که با من به خوبی کشنده شتاب
# target sentence:
# مدارید تا او بدین روی آب
#
#
# input sentence:
# به پیکار ما پیش آرد سپاه
# model output:
# که با او به گیتی سزاوار گاه
# target sentence:
# مگر باز خواهیم زوکین شاه
#
#
# input sentence:
# ازان پس بپرسید کز نامدار
# model output:
# که با او به گیتی به کار زار
# target sentence:
# که ماند ایچ فرزند کاید به کار
#
#
# input sentence:
# جهاندار شه را برادر به دست
# model output:
# که با او به یزدان پرست
# target sentence:
# پسر گر نبود ایچ دختر به دست
#
#
# input sentence:
# که او را بیاریم و یاری دهیم
# model output:
# به پیش سپاه آن گرامی رهی
# target sentence:
# به ماهوی بر کامگاری دهیم
#
#
# input sentence:
# بدو گفت به رسام کای شهریار
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# سرآمد برین تخمهٔ بر روزگار
#
#
# input sentence:
# بران شهرها تازیان راست دست
# model output:
# که با او به یزدان پرست
# target sentence:
# که نه شاه ماند نه یزدان پرست
#
#
# input sentence:
# چو بشنید بیژن سپه برگرفت
# model output:
# به پیش اندرون ساخته بر سرش
# target sentence:
# ز کار جهان دست بر سرگرفت
#
#
# input sentence:
# طلایه بیامد که آمد سپاه
# model output:
# به پیش اندرون ساخته رزمگاه
# target sentence:
# به پیکند سازد همی رزمگاه
#
#
# input sentence:
# سپاهی بکشتی برآمد ز آب
# model output:
# که با او به گیتی همی آفتاب
# target sentence:
# که از گرد پیدا نبود آفتاب
#
#
# input sentence:
# سپهدار بیژن به پیش سپاه
# model output:
# که با او به پیش اندرون ساخته
# target sentence:
# بیامد که سازد همی رزمگاه
#
#
# input sentence:
# چو ماهوی سوری سپه را بدید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# تو گفتی که جانش ز تن برپرید
#
#
# input sentence:
# ز بس جوشن و خود و زرین سپر
# model output:
# که با او به یزدان بخواند
# target sentence:
# ز بس نیزه و گر ز وچاچی تبر
#
#
# input sentence:
# غمی شد برابر صفی برکشید
# model output:
# به پیش اندرون ساخته برکشید
# target sentence:
# هوا نیلگون شد زمین ناپدید
#
#
# input sentence:
# چو بیژن سپه را همه راست کرد
# model output:
# به پیش اندرون ساخته کرد
# target sentence:
# به ایرانیان برکمین خواست کرد
#
#
# input sentence:
# بدانست ماهوی و از قلبگاه
# model output:
# که با او به گیتی ندارد سپاه
# target sentence:
# خروشان برفت ازمیان سپاه
#
#
# input sentence:
# نگه کرد بیژن درفشش بدید
# model output:
# به پیش اندرون ساخته برکشید
# target sentence:
# بدانست کو جست خواهد گزید
#
#
# input sentence:
# به برسام فرمود کز قلبگاه
# model output:
# به پیش سپاه اندر آرم سپاه
# target sentence:
# به یکسو گذار آنک داری سپاه
#
#
# input sentence:
# نباید که ماهوی سوری ز جنگ
# model output:
# که با من به خوبی زمانی درنگ
# target sentence:
# بترسد به جیحون کشد بی درنگ
#
#
# input sentence:
# به تیزی ازو چشم خود برمدار
# model output:
# که با من به خوبی کشنده زینهار
# target sentence:
# که با او دگرگونه سازیم کار
#
#
# input sentence:
# چو برسام چینی درفشش بدید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# سپه را ز لشکر به یکسو کشید
#
#
# input sentence:
# همی تاخت تاپیش ریگ فرب
# model output:
# به پیش اندرون ساخته لب
# target sentence:
# پر آژنگ رخ پر ز دشنام لب
#
#
# input sentence:
# مر او را بریگ فرب دربیافت
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# رکابش گران کرد و اندر شتافت
#
#
# input sentence:
# چو نزدیک ماهو برابر به بود
# model output:
# به پیش سپاه اندر آرم نمود
# target sentence:
# نزد خنجر او را دلیری نمود
#
#
# input sentence:
# کمربند بگرفت و او را ز زین
# model output:
# به پیش اندرون ساخته بر زمین
# target sentence:
# برآورد و آسان بزد بر زمین
#
#
# input sentence:
# فرود آمد و دست او را ببست
# model output:
# به پیش اندرون ساخته برنشست
# target sentence:
# به پیش اندر افگند و خود برنشست
#
#
# input sentence:
# همانگه رسیدند یاران اوی
# model output:
# به پیش اندرون گونه ای گوی
# target sentence:
# همه دشت ازو شد پر از گفت و گوی
#
#
# input sentence:
# ببرسام گفتند کاین را مبر
# model output:
# که با من به خوبی کشنده موبدان
# target sentence:
# بباید زدن گردنش راتبر
#
#
# input sentence:
# چنین داد پاسخ که این راه نیست
# model output:
# که این را به خوبی چنو نیست نیست
# target sentence:
# نه زین تاختن بیژن آگاه نیست
#
#
# input sentence:
# همانگه به بیژن رسید آگهی
# model output:
# که گفتی به تخت مهی مهی
# target sentence:
# که آمد بدست آن نهانی رهی
#
#
# input sentence:
# جهانجوی ماهوی شوریده هش
# model output:
# که با من به خوبی چنو دشمن
# target sentence:
# پر آزار و بی دین خداوندکش
#
#
# input sentence:
# چو بشنید بیژن از آن شادشد
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# ببالید وز اندیشه آزاد شد
#
#
# input sentence:
# شراعی زدند از بر ریگ نرم
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# همی رفت ماهوی چون باد گردم
#
#
# input sentence:
# گنهکار چون روی بیژن بدید
# model output:
# به پیش سپاه اندر آمد پدید
# target sentence:
# خردشد ز مغز سرش ناپدید
#
#
# input sentence:
# شد از بیم همچون تن بی روان
# model output:
# که با او به باغ آمد روان
# target sentence:
# به سر بر پراگند ریگ روان
#
#
# input sentence:
# بدو گفت بیژن که ای بدنژاد
# model output:
# که با من به خوبی کشنده درشت
# target sentence:
# که چون تو پرستار کس را مباد
#
#
# input sentence:
# چرا کشتی آن دادگر شاه را
# model output:
# که با او به بیهوده دانا بود
# target sentence:
# خداوند پیروزی و گاه را
#
#
# input sentence:
# پدر بر پدر شاه و خود شهریار
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# ز نوشین روان در جهان یادگار
#
#
# input sentence:
# چنین داد پاسخ که از بدکنش
# model output:
# که این را به خوبی برو سرزنش
# target sentence:
# نیاید مگر کشتن و سرزنش
#
#
# input sentence:
# بدین بد کنون گردن من بزن
# model output:
# به پیش اندرون بر سرش خوار
# target sentence:
# بینداز در پیش این انجمن
#
#
# input sentence:
# بترسید کش پوست بیرون کشد
# model output:
# که با او به گیتی به هامون برش
# target sentence:
# تنش رابدان کینه در خون کشد
#
#
# input sentence:
# نهانش بدانست مرد دلیر
# model output:
# که با او به گیتی به کردار شیر
# target sentence:
# به پاسخ زمانی همی بود دیر
#
#
# input sentence:
# چنین داد پاسخ که ای دون کنم
# model output:
# که با من به خوبی کنم
# target sentence:
# که کین از دل خویش بیرون کنم
#
#
# input sentence:
# بدین مردی و دانش و رای و خوی
# model output:
# که با تو مبادا که آید به کار
# target sentence:
# هم تاج وتخت آمدت آرزوی
#
#
# input sentence:
# به شمشیر دستش ببرید و گفت
# model output:
# که این را به خوبی نباید نهفت
# target sentence:
# که این دست را در بدی نیست جفت
#
#
# input sentence:
# چو دستش ببرید گفتا دو پا
# model output:
# به پیش اندرون ساخته پهلوان
# target sentence:
# ببرید تا ماند ایدر بجا
#
#
# input sentence:
# بفرمود تا گوش و بینیش پست
# model output:
# به پیش اندرون ساخته دست
# target sentence:
# بریدند و خود بارگی برنشست
#
#
# input sentence:
# بفرمود کاین را برین ریگ گرم
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# بدارید تا خوابش آید ز شرم
#
#
# input sentence:
# منادیگری گرد لشکر بگشت
# model output:
# به پیش اندرون نیزه ور برگذشت
# target sentence:
# به درگاه هرخیمه ای برگذشت
#
#
# input sentence:
# که ای بندگان خداوند کش
# model output:
# که با من به گیتی همی داد
# target sentence:
# مشورید بیهوده هرجای هش
# input sentence:
# چو ماهوی باد آنکه بر جان شاه
# model output:
# به پیش سپاه اندر آمد سپاه
# target sentence:
# نبخشود هرگز مبیناد گاه
#
#
# input sentence:
# سه پور جوانش به لشکر بدند
# model output:
# به پیش اندرون بر سرش بدند
# target sentence:
# همان هر سه با تخت و افسر بدند
#
#
# input sentence:
# همان جایگه آتشی بر فروخت
# model output:
# به پیش اندرون ساخته رود
# target sentence:
# پدر را و هر سه پسر را بسوخت
#
#
# input sentence:
# از آن تخمهٔ کس در زمانه نماند
# model output:
# که با من به گیتی نماند ایچ راه
# target sentence:
# وگر ماند هرکو بدیدش براند
#
#
# input sentence:
# بزرگان بارن دوده نفرین کنند
# model output:
# که با من به گیتی کسی را کنند
# target sentence:
# سرازکشتن شاه پرکین کنند
#
#
# input sentence:
# که نفرین برو باد و هرگز مباد
# model output:
# به پیش اندرون ساخته یاد
# target sentence:
# که او را نه نفرین فرستد بداد
#
#
# input sentence:
# کنون زین سپس دور عمر بود
# model output:
# که با من به خوبی نباید شنود
# target sentence:
# چو دین آورد تخت منبر بود
#
#
# input sentence:
# چو بگذشت سال ازبرم شست و پنج
# model output:
# به پیش سپاه اندر آمد بباد
# target sentence:
# فزون کردم اندیشهٔ درد و رنج
#
#
# input sentence:
# به تاریخ شاهان نیاز آمدم
# model output:
# که با او به یزدان پرست
# target sentence:
# به پیش اختر دیرساز آمدم
#
#
# input sentence:
# بزرگان و با دانش آزادگان
# model output:
# که با او به گیتی همی داد
# target sentence:
# نبشتند یکسر همه رایگان
#
#
# input sentence:
# نشسته نظاره من از دورشان
# model output:
# که با من به خوبی کشنده گذر
# target sentence:
# تو گفتی بدم پیش مزدورشان
#
#
# input sentence:
# جز احسنت از ایشان نبد بهره ام
# model output:
# که با من به خوبی نگیرند ام
# target sentence:
# بکفت اندر احسنتشان زهره ام
#
#
# input sentence:
# سربدره های کهن بسته شد
# model output:
# به پیش اندرون ساخته پیشه شد
# target sentence:
# وزان بند روشن دلم خسته شد
#
#
# input sentence:
# ازین نامور نامداران شهر
# model output:
# به پیش سپاه اندر آرم سرش
# target sentence:
# علی دیلمی بود کوراست بهر
#
#
# input sentence:
# که همواره کارش بخوبی روان
# model output:
# به پیش اندرش خشک و جوان
# target sentence:
# به نزد بزرگان روشن روان
#
#
# input sentence:
# حسین قتیب است از آزادگان
# model output:
# که با من به نیکی دهش کرد
# target sentence:
# که ازمن نخواهد سخن رایگان
#
#
# input sentence:
# ازویم خور و پوشش و سیم و زر
# model output:
# که با من به گیتی به گیتی فروز
# target sentence:
# وزو یافتم جنبش و پای و پر
#
#
# input sentence:
# نیم آگه از اصل و فرع خراج
# model output:
# به پیش سپاه اندر آمد سرش
# target sentence:
# همی غلتم اندر میان دواج
#
#
# input sentence:
# جهاندار اگر نیستی تنگ دست
# model output:
# به پیش سپاه اندر آرم زیان
# target sentence:
# مرا بر سرگاه بودی نشست
#
#
# input sentence:
# چو سال اندر آمد به هفتاد ویک
# model output:
# به پیش اندرون ساخته چند گوشوار
# target sentence:
# همی زیر بیت اندر آرم فلک
#
#
# input sentence:
# همی گاه محمود آباد باد
# model output:
# به پیش سپاه اندر آمد بباد
# target sentence:
# سرش سبز باد و دلش شاد باد
#
#
# input sentence:
# چنانش ستایم که اندر جهان
# model output:
# که با من به نیکی دهش آشکار
# target sentence:
# سخن باشد از آشکار ونهان
#
#
# input sentence:
# مرا از بزرگان ستایش بود
# model output:
# که با من به خوبی نباید شنود
# target sentence:
# ستایش ورا در فزایش بود
#
#
# input sentence:
# که جاوید باد آن خردمند مرد
# model output:
# که با من به خوبی زمانی کرد
# target sentence:
# همیشه به کام دلش کارکرد
#
#
# input sentence:
# همش رای و هم دانش وهم نسب
# model output:
# که با او به گیتی همی بشمرد
# target sentence:
# چراغ عجم آفتاب عرب
#
#
# input sentence:
# سرآمد کنون قصهٔ یزدگرد
# model output:
# که با من به خوبی نباید شنود
# target sentence:
# به ماه سفندار مد روز ارد
#
#
# input sentence:
# ز هجرت شده پنج هشتادبار
# model output:
# که با من به خوبی چنو نیست
# target sentence:
# به نام جهانداور کردگار
#
#
# input sentence:
# چواین نامور نامه آمد ببن
# model output:
# که با او به بیهوده دانا سخن
# target sentence:
# ز من روی کشور شود پرسخن
#
#
# input sentence:
# از آن پس نمیرم که من زنده ام
# model output:
# که با من به خوبی نگیرند ام
# target sentence:
# که تخم سخن من پراگنده ام
